# %%
# Create the forward-in-time embedded time series matrix
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.io import wavfile

# Read the audio file
sampling_rate, audio_data = wavfile.read("audio.wav")

# Normalize audio data to the range [-1, 1]
audio_data = audio_data.astype(np.float32) / np.max(np.abs(audio_data))

# Embedding parameters
embedding_dimension = 3  # Choose the embedding dimension
time_delay = 20          # Choose the time delay

# Create the forward-in-time embedded time series matrix
def create_embedded_matrix(data, embedding_dimension, time_delay):
    num_points = len(data) - (embedding_dimension - 1) * time_delay
    embedded_matrix = np.zeros((num_points, embedding_dimension))
    for i in range(num_points):
        for j in range(embedding_dimension):
            embedded_matrix[i, j] = data[i + j * time_delay]
    return embedded_matrix


embedded_matrix = create_embedded_matrix(audio_data, embedding_dimension, time_delay)

# Scatter plot of the embedded points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
# Plot a continuous line through the embedded points
ax.plot(embedded_matrix[:, 0], embedded_matrix[:, 1], embedded_matrix[:, 2], color='blue', linewidth=.5, label='Continuous Line')

ax.set_title("forward-in-time embedded")
ax.legend()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3632\3343093146.py:8: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, audio_data = wavfile.read("audio.wav")

# %%
# Create the backward-in-time embedded time series matrix
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.io import wavfile

# Read the audio file
sampling_rate, audio_data = wavfile.read("audio.wav")

# Normalize audio data to the range [-1, 1]
audio_data = audio_data.astype(np.float32) / np.max(np.abs(audio_data))

# Embedding parameters
embedding_dimension = 3  # Choose the embedding dimension
time_delay = 20          # Choose the time delay


#backward-in-time embedding 
def create_embedded_matrix(data, embedding_dimension, time_delay):
    num_points = len(data) - (embedding_dimension - 1) * time_delay
    embedded_matrix = np.zeros((num_points, embedding_dimension))
    for i in range(num_points):
        for j in range(embedding_dimension):
            embedded_matrix[i, j] = data[i - j * time_delay]  # Adjust indexing here
    return embedded_matrix

embedded_matrix = create_embedded_matrix(audio_data, embedding_dimension, time_delay)

# Scatter plot of the embedded points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
# Plot a continuous line through the embedded points
ax.plot(embedded_matrix[:, 0], embedded_matrix[:, 1], embedded_matrix[:, 2], color='blue', linewidth=.5, label='Continuous Line')

ax.set_title("Backward-in-time embedded")
ax.legend()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3632\3501160246.py:8: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, audio_data = wavfile.read("audio.wav")

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.io import wavfile

# Read the audio file
sampling_rate, audio_data = wavfile.read("audio.wav")

# Normalize audio data to the range [-1, 1]
audio_data = audio_data.astype(np.float32) / np.max(np.abs(audio_data))

# Embedding parameters
embedding_dimension = 3  # Choose the embedding dimension
time_delay = 20          # Choose the time delay

# Create the embedded time series matrix
def create_embedded_matrix(data, embedding_dimension, time_delay):
    num_points = len(data) - (embedding_dimension - 1) * time_delay
    embedded_matrix = np.zeros((num_points, embedding_dimension))
    for i in range(num_points):
        for j in range(embedding_dimension):
            embedded_matrix[i, j] = data[i + j * time_delay]
    return embedded_matrix

embedded_matrix = create_embedded_matrix(audio_data, embedding_dimension, time_delay)

# Scatter plot of the embedded points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(embedded_matrix[:, 0], embedded_matrix[:, 1], embedded_matrix[:, 2], s=.8, c='blue', label='Scattered Line')
ax.set_title("forward-in-time")
ax.legend()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3632\4258970374.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, audio_data = wavfile.read("audio.wav")

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.io import wavfile

# Read the audio file
sampling_rate, audio_data = wavfile.read("audio.wav")

# Normalize audio data to the range [-1, 1]
audio_data = audio_data.astype(np.float32) / np.max(np.abs(audio_data))

# Embedding parameters
embedding_dimension = 3  # Choose the embedding dimension
time_delay = 20          # Choose the time delay

#backward-in-time embedding 
def create_embedded_matrix(data, embedding_dimension, time_delay):
    num_points = len(data) - (embedding_dimension - 1) * time_delay
    embedded_matrix = np.zeros((num_points, embedding_dimension))
    for i in range(num_points):
        for j in range(embedding_dimension):
            embedded_matrix[i, j] = data[i - j * time_delay]  # Adjust indexing here
    return embedded_matrix

embedded_matrix = create_embedded_matrix(audio_data, embedding_dimension, time_delay)

# Scatter plot of the embedded points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(embedded_matrix[:, 0], embedded_matrix[:, 1], embedded_matrix[:, 2], s=.8, c='blue', label='Scattered Line')
ax.set_title("backward-in-time")
ax.legend()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3632\2392045232.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, audio_data = wavfile.read("audio.wav")
